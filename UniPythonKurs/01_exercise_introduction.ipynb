# %% [markdown]
# *Authors:*

# %% [markdown]
# # Exercise 1: Introductions

# %% [markdown]
# ## Problems

# %% [markdown]
# General information about points and conditions to pass can be found in the instructions "00" notebook.

# %% [markdown]
# ### Solving the problems
#
# If you encounter a cell like
#
# ![image.png](attachment:c4e0d189-0976-450b-ae9e-fe5ab4f61ef8.png)
#
# you are supposed to change it to
#
# ![image.png](attachment:47fe6453-3610-4271-9be2-1e3262be6554.png)
#
# The return value of the cell (in this example output `[1]`) must be the solution of the task.
# Do not delete or remove these cells.
# Only enter or change code below the comment that tells you to.
# Important for future lessons: Do not use `print()` for these problem solutions unless it is explicitly stated.
# You will only learn about `print()` in the next lesson, anyway.

# %% [markdown]
# #### Problem 1

# %% [markdown]
# Your first task is to calculate the sum of *all* (integer) numbers from 1 to 9

# %%
# PROBLEM (1)
# This first problem is worth 1 point.
# Do not move or delete this cell.
# The following problems will have a similar structure.

# SOLUTION
# This solution part will be stripped for the student version of the notebooks.
# It must be a sample solution that determines the exact cell return value that
# students are expected to generate with their versions.
1+2+3+4+5+6+7+8+9

# %% [markdown]
# #### Problem 2

# %% [markdown]
# What is the floating point ratio of 78582 and 2348?

# %%
# PROBLEM (1)

# SOLUTION
78582 / 2348

# %% [markdown]
# #### Problem 3

# %% [markdown]
# What is the integer ratio (i.e. rounded to the next lower integer) of 78582 and 2348?

# %%
# PROBLEM (1)

# SOLUTION
78582 // 2348

# %% [markdown]
# #### Problem 4

# %% [markdown]
# What is the remainder of the division of 78582 by 2348?

# %%
# PROBLEM (1)

# SOLUTION
78582 % 2348

# %% [markdown]
# #### Problem 5

# %% [markdown]
# Calculate the product of 2348 and 33; add 1098

# %%
# PROBLEM (1)

# SOLUTION
2348 * 33 + 1098

# %% [markdown]
# #### Problem 6

# %% [markdown]
# Calculate the fourth power of $\pi$ and subtract Euler's number $e$
# Use $\pi$ and $e$ from the math module.
# Do not use `math.pow()` to calculate the power.

# %%
# PROBLEM (1)

import math

# SOLUTION
math.pi ** 4 - math.e

# %% [markdown]
# #### Problem 7

# %% [markdown]
# Calculate the base-2 logarithm of 2147483648
# Use the proper function from the math module (similar to something we did today, already)

# %%
# PROBLEM (1)

import math

# SOLUTION
math.log2(2147483648 )

# %% [markdown]
# #### Problem 8

# %% [markdown]
# Calculate the number of ways to choose 8 items from 15 items **without repetition** and **without order**.
# Have a look at the documentation of the math module and select a function thsolves this problem.

# %%
# PROBLEM (2)

import math

# SOLUTION
math.comb(15, 8)

# %% [markdown]
# #### Problem 9

# %% [markdown]
# Run this command in a terminal:
# ```
# cat ~mrieger/public/python-ss25-semester/01_terminal_problem.txt
# ```
# Which number do you see? Simply type it in the field where the solution is supposed to go:

# %%
# PROBLEM (1)
# SOLUTION
42424242

# %% [markdown]
# When you have solved all problems, follow the instructions in the "00" notebook to upload your first notebook to moodle. Again, pay special attention to these important points:
# - make sure the notebook **runs from top to bottom** in one go
# - **save the notebook properly** before downloading
#
# The "00" notebook contains instructions to assure these points.
