# %% [markdown]
# # Lesson 0: Instructions to set things up
#
# This is supposed to be a setup instruction to get your Notebooks running. Indeed, it is a first *Jupyter Notebook* that you will probably see as a PDF-Version or something similar for now.
#
# Please contact [admin@physnet.uni-hamburg.de](mailto:admin@physnet.uni-hamburg.de) if you do NOT have your PHYSNet credentials yet.
#
# Please follow these instructions:
#
# ## Login at JupyterHub
# with your PHYSNet credentials: https://jhub.physnet.uni-hamburg.de
#
# ![image300px.png](attachment:1ee0712e-bfa8-44d1-bd91-7bf8b4746f49.png)
#
# You can keep the default settings in the following "Server Options" and click "Start" (the last field will contain a working directory including your user name instead of "jolange"). This might take some seconds.
#
# ![image500px.png](attachment:d5e2687d-776b-4803-8f24-83d71e22c7db.png)

# %% [markdown]
# ## Open a first notebook
#
# In the "Launcher" tab, in the notebook section, choose the one highlighted here:
#
# ![image500px.png](attachment:773b7ab1-8ac2-497c-ada8-3b0aeeaaff59.png)
#
# This specifies a so-called *kernel*. In the notebook that opens you can check it in the right corner:
#
# ![image800px.png](attachment:8f6bb555-dc4b-4a2c-b9f5-1768c4d6b953.png)
#
# If you somehow picked the wrong one, you can click it here and change it. It is important to use the right kernel version throughout this course.
#
# In the tab title you can see the notebook's name `Untitled.py`. You can rename it if you right-click the title. We will only use this notebook temporarily to set things up, so you don't need to. The proper notebooks we will use in a few moments will have more useful names.

# %% [markdown]
# ## Set up a folder structure and copy your first notebook
#
# The marked area shown here is called an *input cell*:
#
# ![image800px.png](attachment:1631211c-9536-4fc0-b7a1-2ea4684575c1.png)
#
# **Copy the following two lines** into the empty cell that you see:

# %%
# !mkdir -p computeranwendungen-grundlagen
!~mrieger/public/get_notebook 00
# !mv 00_student_instructions.ipynb computeranwendungen-grundlagen

# %% [markdown]
# It should look like the following. Press the play button as highlighted:
#
# ![play_button.png](attachment:e913f239-3fec-4513-8880-eac9d488761d.png)

# %% [markdown]
# A folder was created for you and a file was copied.
#
# In the file browser to the left you can click the reload-icon and see the folder we created. Double click `computeranwendungen-grundlagen` to open it. It will contain the file `00_student_instructions.ipynb` which is contains exactly the instructions you are reading right now, but as a *Jupyter Notebook*.
#
# You can switch to that notebook now and **continue here**.

# %% [markdown]
# ## Welcome back
# From here on you should not follow the instructions in any PDF any longer, but be in the notebook `00_student_instructions.ipynb` where you can execute cells.
#
# Focus the next cell and click the play button again to execute it. It shows you the current working directory which should end on `computeranwendungen-grundlagen`

# %%
# !pwd

# %% [markdown]
# ## Copy your first *real* notebook
# Now let's copy the first *real* notebook that contains lesson 1. We execute something similar as we did with the temporary notebook `Untitled.py`. We do not need to create a folder, though, because it exists already and we are currently working in a notebook exactly inside that folder, which is our *working directory*.
#
# When we execute the following command, `01.ipynb` will be placed in the working directory. It should show up in the file browser (after hitting the refresh button).

# %%
!~mrieger/public/get_notebook 01

# %% [markdown]
# You are ready to start the first coding session :-)
#
# This way you can get a fresh copy of the corresponding notebook at the beginning of each lesson (`01`, `01_exercise`, `02`, `02_exercise`, `03`, `03_exercise`, ...).
#
# You can check what is present already if you omit the notebook number:

# %%
!~mrieger/public/get_notebook

# %% [markdown]
# The notebooks that are only listed with a number e.g. `01` are the so called **teaching notebooks** and the notebooks listed with "exercise" in addition to the number e.g. `01_exercise` are the so called **exercise notebooks**.
# The **teaching notebooks** will be provided always one week in advance, the **exercise notebooks** will be available when the session starts.
# You can also copy the **exercise notebook** before a session, if it is already provided, to have a first look. But you should always start with a fresh copy at the beginning of the session, because there might be last-minute changes.
# **Caution**: The `get_notebook` command is merciless: It will overwrite a file with the same name if it already exists. Keep this in mind if you already made changes to a notebook and for some reason want to start fresh. In that case, please copy or rename your notebook before copying a fresh one. (Can be done in the file browser.)

# %% [markdown]
# ## Structure of the course
#
# ### 1. Preparation at home
#
# The **teaching notebooks** will be provided one week in advance. Get the notebook and work through the **first part** of the **teaching notebook**. It provides all information you need for the lesson. Read through the information and execute the cells contained in the example code. Feel free to play with the existing examples e.g. change some parameters, print some variables, ... You can also add cells with similar calculations. Do everything that you want and that helps you to understand the content of the notebook. It's your notebook!
#
# If the notebook contains content that you don't understand, note your questions and feel free to ask in the next exercise session.
#
# ### 2. In class exercises and live demonstrations
#
# In the first half of the exercise session we'll work on the **second part** of the **teaching notebook**. The second part of the **teaching notebook** contains exercises and live demonstrations. There will be tasks that you should try to solve in class. Feel free to discuss with other students in the room or ask your tutor in case you have any problems or general questions. There might be also tasks that will be solved live and interactively by the tutor in front of the class (like a blackboard lecture). The educational goal of this section is that you get familiar with the content of the lesson (the stuff you read about in part 1) and that you are able to apply the gained knowledge on your own.
#
# ### 3. Graded exercise
#
# Get the **exercise notebook** and solve the tasks in the notebook. You can do this alone or together with a partner. You should use the second half of the exercise session to solve the tasks. You can continue working on the tasks after the exercise session until Sunday 23:59 Hamburg time. In this part you have to prove that you learned the content of the lesson and that you are able to use it on your own. You have to hand in the **exercise notebook** and it will get graded. The grades of your **exercise notebooks** will decide whether you pass or fail the course. More about solving and handing in the exercises and the criterions to pass the course can be found in the sections below in this notebook.

# %% [markdown]
# ## Solving problems and handing in solutions
# Each lesson will contain a number of problems that you need to solve.
#
# Your solution must be handed in **via moodle**, simply in form of a notebook. Please proceed as follows if you are ready to hand in:
#
# ### General information on problems
# Cells that start with the comment line `# PROBLEM (N)` contain a problem that you are supposed to solve. It is worth N points for a correct solution and 0 otherwise. There will not be fractional points. The idea is to have enough (easy) problems to gain the required points for passing the course, even if you lose all points for a slightly wrong solution. Do not delete or move these cells!
#
# Important information on **Points and Grading**:
#
# Each lesson will be worth 10 points and you need
# - at least 3 points per lesson and
# - at least 55 points in total
# to pass.
#
# We will remove the TWO weakest submission (lessons) from the count for both conditions above.
#
# For the **semester course** submissions close on Sundays 23:59 Hamburg time.
#
# Only hand in **exercise notebooks** that you or your partner copied with the `get_notebook` script to your own directories. It is explicitly forbidden to hand in notebooks
# - from other participants
# - from previous semesters (tasks will be different anyways)
#
# Your tutor can help you to **upload the solutions to Moodle for grading** if you have questions that are not answered in the instruction notebook.
#
# The grading in moodle will only contain very minimal feedback for wrong solutions. If you cannot spot your mistakes,
# - talk to other students and discuss your code, because that's a good exercise for what you would need to do in "the real world" later, and/or
# - ask you tutor in the next lesson for feedback.
#
# Please do not write messages with questions about your solutions, because these things require interactively looking at your code together.

# %% [markdown]
# ### First make sure that your notebook runs from top to bottom without errors
# You can click the "restart kernel and run all" button:
#
# ![image800px.png](attachment:f897db4c-5712-436e-8998-5aa1d0fbb2f9.png)
#
# If a cell fails, you will see a red error output there and the execution will stop. You need to fix this and try to re-run again. "Fixing" can also mean to just comment out (you will learn that) the cell if it is not needed (we actually only check the PROBLEM-cells for grading -- see lesson 01).  Some of the notebooks you will receive contain cells that fail, because we want to demonstrate errors.
#
# Once you have properly fixed everything, pressing "restart kernel and run all" should lead to a notebook with all cells executed including the very last one.
#
# **Make sure the notebook runs from top to bottom in one go! If it gets stuck somehwere (e.g. an infinite loop), it cannot be graded!**

# %% [markdown]
# ### Download the notebook as `.ipynb`
#
# Optionally: before you download, you can "Clear All Outputs" to reduce the size of the notebook (mostly makes a difference once we will create plots and pictures). We will re-execute your notebook anyway for grading.
#
# ![image200px.png](attachment:3560b7e0-82fb-4270-9b5d-8306fd8d314d.png)

# %% [markdown]
# To download the notebook, make sure you **saved it properly** (File, Save Notebook).
#
# ![image200px.png](attachment:998f5249-e072-447d-a1a4-b78a31c79417.png)
#
# You can right-click the file in the file browser and choose "Download":
#
# ![image200px.png](attachment:1b4c4783-6b31-4056-aaf9-9dda105748fa.png)
#
# Store the `.ipynb` file somewhere on your local computer. If you did not save the notebook and upload an outdated version to moodle, **you might lose points**!

# %% [markdown]
# ### Upload in moodle
# Navigate to the assignment in moodle:
#
# ![image800px.png](attachment:b25be459-78a3-4566-9191-288fdd6a7ddb.png)
#
# Click on "Add submission":
#
# ![image.png](attachment:1966b3ba-ab84-4391-916f-ad765ca7998d.png)

# %% [markdown]
# Click on "Add...":
#
# ![image800px.png](attachment:bbfa0a1f-8b10-4de9-9fc1-429010f50657.png)
#
# And in the file picker, choose "Upload a file", "Browse", select the `.ipynb` notebook and click "Upload this file"
#
# ![image500px.png](attachment:1d08f7d3-935a-4392-bc4f-6693d5e5d548.png)
#
# **Important**: upload only that single file and exactly with the right file extension! Only upload the **exercise notebook** and not the **teaching notebook**.
#
# Finally, click "Save Changes"

# %% [markdown]
# #### *Just for display purposes:*
#
# when exporting, remove these inputs using
# ```
# jupyter nbconvert 00_student_instructions.ipynb --TagRemovePreprocessor.remove_input_tags='{"rm_input"}' --to html
# ```
#
# When presenting or viewing, execute this once (css-hack for scaled image display):

# %%
# %%html
# <style>
# img[alt="image200px.png"] {
#     max-width: min(100%, 200px);
# }
# img[alt="image300px.png"] {
#     max-width: min(100%, 300px);
# }
# img[alt="image500px.png"] {
#     max-width: min(100%, 500px);
# }
# img[alt="image800px.png"] {
#     max-width: min(100%, 800px);
# }
# </style>
# Out:
# <style>
# img[alt="image200px.png"] {
#     max-width: min(100%, 200px);
# }
# img[alt="image300px.png"] {
#     max-width: min(100%, 300px);
# }
# img[alt="image500px.png"] {
#     max-width: min(100%, 500px);
# }
# img[alt="image800px.png"] {
#     max-width: min(100%, 800px);
# }
# </style>
