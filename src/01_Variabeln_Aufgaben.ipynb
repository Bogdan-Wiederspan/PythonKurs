# %% [markdown]
# # Typische Fehlercodes
# Fehler im Code zu finden ist so ziemlich der wichtigste Skill den ihr euch aneignen könnt.
# Diesen Skill muss man aber auch üben.
# Hier unten gibt es Code wovon keiner Funktioniert.
#
# Lest euch die Fehlermeldungen genau durch und korrigiert die Fehler.

# %%
def my_function(x):
    y = x + 1
     z = y * 2
    return z

# %%
# EOL means END OF LINE
print("Obi-Wan Kenobi: Hello There!")
print("General Grievous: General Kenobi!)

# %%
very_complicated_variable_name = "Anakin Skywalker"
print("My Name is ", very_complucated_varibl_nam)

# %%
import math
# calculate the square root of 4
math.sqr(4)

# %%
return = "this string breaks python"

# %%
def print_secret_number(secret_number):
    print("Your secret number is", secret_number)

print_secret_number()

# %%
def say_hello():
    print("Hello, my dear friend")

say_hello("Joe")

# %%
def my_func(argument1 = 2)
    return argument1 * 2

# %% [markdown]
# ## Begrüßung mit Eingabe (leicht)
# In Python kannst du Eingaben des Users per `input()` anfordern.
# Erfrage `name` und `alter` einer Person und gib eine personalisierte Begrüßung aus in der Form: `Hallo <name>, du bist <alter> Jahre alt.`.
# Achte darauf, `alter` in einen `int` umzuwandeln.

# %%
name = input('Name: ')
age = int(input('Alter: '))
print(f'Hallo {name}, du bist {age} Jahre alt.')

# %% [markdown]
# ## Variablen tausch (leicht)
# In Python kannst du auch mehrere Variabeln gleichzeitig setzen.
# Das erreichst du über Kommas und den Zuordnungsoperator (bsp: `a, b = 0, 1`).
#
# Häufig ist es so das du bei Monitoren zwischen Porträt und Landschafts Modus wechseln kannst.
# Dafür wird intern die Höhe und Breite vertauscht.
# Wie würdest du diese Operation ausführen? Wie viele Schritte brauchst du mindestens dafür?

# %%
höhe = 1920
breite = 1080

# Solution
höhe, breite = breite, höhe
# oder
tmp = höhe
höhe = breite
breite = tmp

# %% [markdown]
# ## BMI ausrechnen (leicht)
# Der BMI (Body Mass Index) ist eine typische Größe die einem bei dem Thema abnehmen auftaucht.
# Er versucht Körpergröße und Gewicht in nur einer Zahl zu beschreiben.
# Die Formel dafür lautet: $$\frac{Gewicht}{Höhe^2}$$.
# Das Gewicht ist hierbei in Kilogramm und die Höhe in cm
# Welche BMI hat Marina und Klaus?
#
# Kannst du das auch als Funktion schreiben?

# %%
maria_gewicht = 75 # kg
maria_höhe = 160 # cm

klaus_gewicht = 90000 # g
klaus_höhe = 1.2 # meter


# Solution
maria_bmi = maria_gewicht / maria_höhe**2
klaus_bmi = (klaus_gewicht / 1000) / (klaus_höhe * 100)**2

def bmi(gewicht, höhe):
    return gewicht / höhe**2

# %% [markdown]
# ## Fläche und Volumen berechnen (mittel)
# Schreibe ein Funktion die für einen gegeben Radius das Volumen und die Fläche einer Kugel berechnet.  Benutze eine Variabel Pi die du mit 3.14 annäherst.

# %%
PI = 3.14

def area_ball(radius):
    return 2 * PI * radius

def volumen(radius):
    return 4 / 3 * radius**3 * PI

# %% [markdown]
# ## Winkelmaß
# 360° entspricht dabei 2 pi Bogenmaß.
# Das heißt 1° entpricht 2 pi / 360° Bogenmaß.
#
# Schreibe ein Programm, das zu einem gegebenen Winkel in Bogenmass umrechnet.
# Schreibe ebenfalls ein Programm das den Rückweg berechnet.
# Mache den Test dem du 0°, 74° und 180° in Bogenmaß umrechnest und zurück.

# %%
def bogenmaß(winkel):
    return 2 * PI / 360 * winkel

def winkel(bogenmaß):
    return 360 / (2 * PI) * bogenmaß

for win in (0, 74, 180):
    bogen_maß = bogenmaß(win)
    winkel_zurück = winkel(bogen_maß)
    print(f"Das Bogenmaß ist {bogen_maß} und zurück in Grad: {winkel_zurück}")

# %% [markdown]
# ## Würfel wurf:
# Python besitzt ein *random* *Modul* [siehe documentation](https://docs.python.org/3/library/random.html) mit dem ihr Zufalls Prozesse Simulieren könnt.
# Die `random.choices` Funktion ermöglicht es aus einer List von Möglichkeiten mit einer Wahrscheinlich diese zu ziehen.
#
# Schreibe ein Funktion die einen gezinkten Würfel simulieren.
# Die 6 taucht hier 2x so häufig auf wie alle anderen Werte.
# Die Argumente der choices Funktion nimmt eine Ansammlung von Komma separierten Werten, auch *Liste bzw. Tupel* genannt.
# Diese könnt ihr mit `[WERT1, WERT2, ...]` bzw. `(WERT1, WERT2, ...)` erstellen.
# Für einen Münzwurf würde das so aussehen:
# ````python
# ergebnis = random.choices(("Kopf", "Zahl"), (1/2, 1/2), k = k)
# `````
